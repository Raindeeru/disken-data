# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "data.csv"
df = pd.read_csv(file_path)

# %%
sns.set_palette("colorblind")

# %%
df
# Out:
#       File Size  Block Size       Speed Encryption Operation  Trial
# 0            64           4   5735102.0       luks      read      1
# 1            64           8  10821524.0       luks      read      1
# 2            64          16  15972885.0       luks      read      1
# 3            64          32  12902017.0       luks      read      1
# 4            64          64  64000000.0       luks      read      1
# ...         ...         ...         ...        ...       ...    ...
# 2425    1048576        1024    704481.0       vera     write      3
# 2426    1048576        2048     92201.0       vera     write      3
# 2427    1048576        4096     61320.0       vera     write      3
# 2428    1048576        8192     66489.0       vera     write      3
# 2429    1048576       16384    110827.0       vera     write      3
#
# [2430 rows x 6 columns]

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="Encryption", y="Speed", hue="Operation", data=df)
plt.title("Speed by Encryption and Operation")
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1) 
sns.lineplot(x="Block Size", y="Speed", hue="Encryption", data=df[df["Operation"] == "read"], markers=True)
plt.title("Speed vs. Block Size (Read)")
plt.xlabel("Block Size")
plt.ylabel("Speed")
# Out:
# Text(0, 0.5, 'Speed')

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 2)  # 2 rows, 1 column, second plot
sns.lineplot(x="Block Size", y="Speed", hue="Encryption", data=df[df["Operation"] == "write"], markers=True)
plt.title("Speed vs. Block Size (Write)")
plt.xlabel("Block Size")
plt.ylabel("Speed")
# Out:
# Text(0, 0.5, 'Speed')

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1) 
sns.lineplot(x="File Size", y="Speed", hue="Encryption", data=df[df["Operation"] == "read"], markers=True)
plt.title("Speed vs. File Size (Read)")
plt.xlabel("File Size")
plt.ylabel("Speed")
# Out:
# Text(0, 0.5, 'Speed')

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1) 
sns.lineplot(x="File Size", y="Speed", hue="Encryption", data=df[df["Operation"] == "write"], markers=True)
plt.title("Speed vs. File Size (Write)")
plt.xlabel("File Size")
plt.ylabel("Speed")
# Out:
# Text(0, 0.5, 'Speed')
